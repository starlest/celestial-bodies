# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# # Obtain Moons

# %%
list_of_moons_page = requests.get('https://littleastronomy.com/moon-names/')
moon_more_info_page = requests.get('https://courses.lumenlearning.com/suny-astronomy/chapter/selected-moons-of-the-planets/')
list_of_planets_page = requests.get('https://en.wikipedia.org/wiki/Planet#Solar_System');

# %%
soup = BeautifulSoup(list_of_moons_page.text, 'lxml')

# Initialize the table
headers = ['name', 'planet', 'name_meaning']
df_moon = pd.DataFrame(columns=headers)

# Enter data for each row into the dataframe
table = soup.find("table")
for table_row in table.find_all('tr')[1:]:
  data = [table_data.text.strip() for table_data in table_row.find_all('td')]
  df_moon.loc[len(df_moon)] = data

# Display the table
df_moon.head()
# Out:
#      name   planet                                      name_meaning
# 0    Moon    Earth                                           “month”
# 1  Phobos     Mars                       Greek god of fear and panic
# 2  Deimos     Mars                     Greek god of dread and terror
# 3      Io  Jupiter  Ancestor to Perseus, Cadmus, Heracles, and Minos
# 4  Europa  Jupiter                     Mother of king Minos of Crete

# %%
def convert_string_to_integer(str):
    str_integer = ''.join([n for n in str if n.isdigit()])
    return None if str_integer == '' else int(str_integer)

# %%
soup = BeautifulSoup(moon_more_info_page.text, 'lxml')

# Initialize the table
headers = ['name', 'year_discovered', 'diameter_in_km']
df_moon_additional_info  = pd.DataFrame(columns=headers)

# Enter data for each row into the dataframe
table = soup.find("table")
for table_row in table.find_all('tr')[2:]:
  rows = table_row.find_all('td')
  data = np.array([table_data.text.strip() for table_data in rows])
  selected_data = data[[1, 2, 5]] if len(data) == 8 else data[[0, 1, 4]]
  selected_data[1] = convert_string_to_integer(selected_data[1])
  table_idx = len(df_moon_additional_info)
  df_moon_additional_info.loc[table_idx] = selected_data

df_moon_additional_info.replace(to_replace='None', value=np.nan, inplace=True)

# Display the table
df_moon_additional_info.head()
# Out:
#        name year_discovered diameter_in_km
# 0      Moon             NaN           3476
# 1    Phobos            1877             23
# 2    Deimos            1877             13
# 3  Amalthea            1892            200
# 4     Thebe            1979             90

# %%
# outer join
df_moon_final = pd.merge(df_moon, df_moon_additional_info, on='name', how='outer')

# %%
# check if there are null values
print("Null values: ", df_moon_final.isnull().sum().sum())

# remove rows with null values
df_moon_final.dropna(inplace=True)

# check there are no more null values
print("Null values: ", df_moon_final.isnull().sum().sum())
# Out:
# Null values:  381
# Null values:  0

# %%
df_moon_final.head(6)
# Out:
#        name   planet                                       name_meaning  \
# 1    Phobos     Mars                        Greek god of fear and panic
# 2    Deimos     Mars                      Greek god of dread and terror
# 3        Io  Jupiter   Ancestor to Perseus, Cadmus, Heracles, and Minos
# 4    Europa  Jupiter                      Mother of king Minos of Crete
# 5  Ganymede  Jupiter  Male hero of Troy. Served as Zeus cup-bearer i...
# 6  Callisto  Jupiter  One of the nymphs. Daughter of king Lycaon and...
#
#   year_discovered diameter_in_km
# 1            1877             23
# 2            1877             13
# 3            1610           3630
# 4            1610           3138
# 5            1610           5262
# 6            1610           4800

# %%
must_have_planets = df_moon_final.planet.unique() 
print(must_have_planets)
# Out:
# ['Mars' 'Jupiter' 'Saturn' 'Uranus' 'Neptune']

# %% [markdown]
# Missing one must have planet. So let's manually add a moon related to the planet.

# %%
df_moon_final.loc[len(df_moon_final)] = ['Nix', 'Pluto', 'Geek Goddess of the night', 2005, 46]

# %%
must_have_planets = df_moon_final.planet.unique() 
print(must_have_planets)
# Out:
# ['Mars' 'Jupiter' 'Saturn' 'Uranus' 'Neptune' 'Pluto']

# %% [markdown]
# # Obtain Planets

# %%
def remove_non_alpha(str):
    return ''.join([i for i in str if i.isalpha() or i.isspace()]);

# %%
soup = BeautifulSoup(list_of_planets_page.text, 'lxml')

# Initialize the table
headers = ['name', 'orbital_period_in_years', 'rotation_period_in_days', 'has_moon']
df_planets = pd.DataFrame(columns=headers)

# Enter data for each row into the dataframe
table = soup.find_all("table")[4]
for table_row in table.find_all('tr')[2:]:
  rows = table_row.find_all('td')[1:]
  data = np.array([table_data.text.strip() for table_data in rows])
  
  if len(data) == 0:
    continue
  
  selected_data = data[[0, 4, 7, 8]]
  selected_data[0] = remove_non_alpha(selected_data[0]) # clean string
  df_planets.loc[len(df_planets)] = selected_data

# Replace '?' with NaN
df_planets = df_planets.replace('?', np.NaN)

# Modify the values in "has_moon" column
df_planets['has_moon'] = df_planets['has_moon'].astype(int)
df_planets['has_moon'] = df_planets['has_moon'].apply(np.sign).replace({0: False, 1: True})

# Display the table
df_planets
# Out:
#         name orbital_period_in_years rotation_period_in_days  has_moon
# 0    Mercury                    0.24                   58.65     False
# 1      Venus                    0.62                  243.02     False
# 2      Earth                    1.00                    1.00      True
# 3       Mars                    1.88                    1.03      True
# 4    Jupiter                   11.86                    0.41      True
# 5     Saturn                   29.45                    0.44      True
# 6     Uranus                   84.02                    0.72      True
# 7    Neptune                  164.79                    0.67      True
# 8      Ceres                    4.60                    0.38     False
# 9      Orcus                   247.5                     NaN      True
# 10     Pluto                   247.9                    6.39      True
# 11    Haumea                   283.8                    0.16      True
# 12    Quaoar                   288.0                    0.74      True
# 13  Makemake                   306.2                    0.95      True
# 14  Gonggong                   552.5                    0.93      True
# 15      Eris                     559                   15.79      True
# 16     Sedna                   12059                    0.43     False

# %% [markdown]
# ## Check if all must have planets are present

# %%
for planet_name in must_have_planets: 
    if planet_name not in df_planets.name.values: 
        print(planet_name)

# %%
# Add the "planet_id" column
df_planets.reset_index(inplace=True)
df_planets.rename(columns={'index': 'planet_id'}, inplace=True)
df_planets['planet_id'] += 1

# %%
df_planets.tail()
# Out:
#     planet_id      name orbital_period_in_years rotation_period_in_days  \
# 12         13    Quaoar                   288.0                    0.74
# 13         14  Makemake                   306.2                    0.95
# 14         15  Gonggong                   552.5                    0.93
# 15         16      Eris                     559                   15.79
# 16         17     Sedna                   12059                    0.43
#
#     has_moon
# 12      True
# 13      True
# 14      True
# 15      True
# 16     False

# %% [markdown]
# # Creating the first table: moon table (final)

# %%
# Merge moon table and planet table, then match the planet's id and name
df_moon_merged = pd.merge(df_moon_final, df_planets[['planet_id', 'name']], 
                   left_on='planet', right_on='name', 
                   how='inner')

# Drop "planet" and "name_y" columns
df_moon_merged.drop(['planet', 'name_y'], axis=1, inplace=True)

# Change "name_x" column to "name" column
df_moon_merged.rename(columns={'name_x': 'name'}, inplace=True)

# Display the first five rows of the final moon table
df_moon_merged.head()
# Out:
#        name                                       name_meaning  \
# 0    Phobos                        Greek god of fear and panic
# 1    Deimos                      Greek god of dread and terror
# 2        Io   Ancestor to Perseus, Cadmus, Heracles, and Minos
# 3    Europa                      Mother of king Minos of Crete
# 4  Ganymede  Male hero of Troy. Served as Zeus cup-bearer i...
#
#   year_discovered diameter_in_km  planet_id
# 0            1877             23          4
# 1            1877             13          4
# 2            1610           3630          5
# 3            1610           3138          5
# 4            1610           5262          5

# %% [markdown]
# # Creating constellation and star tables

# %% [markdown]
# The constellation that the planet is "in".
#
# [1] The Sky Live, Major Solar System Objects, https://theskylive.com/planets
#
# [2] The Sky Live, Asteroids, https://theskylive.com/asteroids-and-dwarf-planets
#
# [3] 50000 Quaoar. https://usuaris.tinet.cat/klunn/quaoar.html
#
# [4] Wikipedia, 225088 Gonggong, https://en.wikipedia.org/wiki/225088_Gonggong

# %%
planet_constellation = {
    'Mercury' : 'Virgo', #1
    'Venus' : 'Leo', #1
    'Earth' : 'Centaurus',
    'Mars' : 'Taurus', #!
    'Jupiter' : 'Cetus', #!
    'Saturn' : 'Capricornus', #!
    'Uranus' : 'Aries', #!
    'Neptune' : 'Aquarius', #!
    'Ceres' : 'Leo', #2
    'Orcus' : 'Sagittarius', 
    'Pluto' : 'Sagittarius', #2 
    'Haumea' : 'Boötes', #2
    'Quaoar' : 'Ophiuchus', #3
    'Makemake' : 'Coma Berenices', #2 
    'Gonggong' : 'Aquarius', #4
    'Eris' : 'Cetus', #2
    'Sedna' : 'Taurus', #2
    'Salacia' : 'Pegasus', 
    'Varda' : 'Aquarius'
}

# %%
# Turn the dictionary into a table
df_planet_constellation = pd.DataFrame.from_dict(planet_constellation, orient='index').reset_index()
df_planet_constellation.columns = ['planet', 'constellation']
df_planet_constellation
# Out:
#       planet   constellation
# 0    Mercury           Virgo
# 1      Venus             Leo
# 2      Earth       Centaurus
# 3       Mars          Taurus
# 4    Jupiter           Cetus
# 5     Saturn     Capricornus
# 6     Uranus           Aries
# 7    Neptune        Aquarius
# 8      Ceres             Leo
# 9      Orcus     Sagittarius
# 10     Pluto     Sagittarius
# 11    Haumea          Boötes
# 12    Quaoar       Ophiuchus
# 13  Makemake  Coma Berenices
# 14  Gonggong        Aquarius
# 15      Eris           Cetus
# 16     Sedna          Taurus
# 17   Salacia         Pegasus
# 18     Varda        Aquarius

# %% [markdown]
# ## Scraping constellation and its brightest star

# %%
# Get the table from Wikipedia page
page = requests.get('https://en.wikipedia.org/wiki/IAU_designated_constellations')
soup = BeautifulSoup(page.text, 'lxml')
table = soup.find('table', {'class':"wikitable"})
df_constellation = pd.read_html(str(table))
df_constellation = pd.DataFrame(df_constellation[0])

# Choose the selected columns in the table
df_constellation = df_constellation[['Constellation', 'Origin', 'Meaning', 'Brightest star']]
df_constellation.columns = ['name', 'year_discovered', 'meaning', 'star']

# cleaning up the data in the table
df_constellation['name'] = [word.split('/')[0].strip() for word in df_constellation['name']]
df_constellation['year_discovered'] = df_constellation['year_discovered'].replace('ancient (Ptolemy)', '')
df_constellation['year_discovered'] = [year.split(',')[0] for year in df_constellation['year_discovered']]
df_constellation['meaning'] = df_constellation['meaning'].str.capitalize()

# Display the table
df_constellation
# Out:
#           name year_discovered  \
# 0    Andromeda
# 1       Antlia            1763
# 2         Apus            1603
# 3     Aquarius
# 4       Aquila
# ..         ...             ...
# 83  Ursa Minor
# 84        Vela            1763
# 85       Virgo
# 86      Volans            1603
# 87   Vulpecula            1690
#
#                                             meaning        star
# 0        Andromeda (the chained maiden or princess)   Alpheratz
# 1                                          Air pump   α Antliae
# 2   Bird-of-paradise/exotic bird/extraordinary bird    α Apodis
# 3                                      Water-bearer   Sadalsuud
# 4                                             Eagle      Altair
# ..                                              ...         ...
# 83                                      Lesser bear     Polaris
# 84                                            Sails  γ2 Velorum
# 85                                 Virgin or maiden       Spica
# 86                                      Flying fish  β Volantis
# 87                                              Fox       Anser
#
# [88 rows x 4 columns]

# %%
df_constellation.star.values
# Out:
# array(['Alpheratz', 'α Antliae', 'α Apodis', 'Sadalsuud', 'Altair',
#        'β Arae', 'Hamal', 'Capella', 'Arcturus', 'α Caeli',
#        'β\xa0Camelopardalis', 'Tarf[9]', 'Cor Caroli', 'Sirius',
#        'Procyon', 'Deneb Algedi', 'Canopus', 'Schedar[9]',
#        'Rigil Kentaurus[9]', 'Alderamin', 'Diphda[9]', 'α Chamaeleontis',
#        'α Circini', 'Phact', 'β Comae Berenices', 'Meridiana[9]',
#        'Alphecca', 'Gienah', 'δ Crateris', 'Acrux', 'Deneb', 'Rotanev',
#        'α Doradus', 'Eltanin[9]', 'Kitalpha', 'Achernar', 'Dalim[9]',
#        'Pollux', 'Alnair', 'Kornephoros', 'α Horologii', 'Alphard',
#        'β Hydri', 'α Indi', 'α Lacertae', 'Regulus', 'Praecipua', 'Arneb',
#        'Zubeneschamali[9]', 'α Lupi', 'α Lyncis', 'Vega', 'α Mensae',
#        'γ Microscopii', 'β Monocerotis', 'α Muscae', 'γ2 Normae',
#        'ν Octantis', 'Rasalhague', 'Rigel', 'Peacock', 'Enif', 'Mirfak',
#        'Ankaa', 'α Pictoris', 'Alpherg', 'Fomalhaut', 'Naos', 'α Pyxidis',
#        'α Reticuli', 'γ Sagittae', 'Kaus Australis', 'Antares',
#        'α Sculptoris', 'α Scuti', 'Unukalhai', 'α Sextantis', 'Aldebaran',
#        'α Telescopii', 'β Trianguli', 'Atria', 'α Tucanae', 'Alioth',
#        'Polaris', 'γ2 Velorum', 'Spica', 'β Volantis', 'Anser'],
#       dtype=object)

# %% [markdown]
# Out of practicality, I would like to remove the star column’s use of Greek letters on their records to our alphabet. And if you check further, the star’s name also contains [9]s, so I’ll omit them as well.

# %%
df_constellation['star'] = df_constellation['star'].apply(remove_non_alpha)

# %%
df_constellation.star.values
# Out:
# array(['Alpheratz', 'α Antliae', 'α Apodis', 'Sadalsuud', 'Altair',
#        'β Arae', 'Hamal', 'Capella', 'Arcturus', 'α Caeli',
#        'β\xa0Camelopardalis', 'Tarf', 'Cor Caroli', 'Sirius', 'Procyon',
#        'Deneb Algedi', 'Canopus', 'Schedar', 'Rigil Kentaurus',
#        'Alderamin', 'Diphda', 'α Chamaeleontis', 'α Circini', 'Phact',
#        'β Comae Berenices', 'Meridiana', 'Alphecca', 'Gienah',
#        'δ Crateris', 'Acrux', 'Deneb', 'Rotanev', 'α Doradus', 'Eltanin',
#        'Kitalpha', 'Achernar', 'Dalim', 'Pollux', 'Alnair', 'Kornephoros',
#        'α Horologii', 'Alphard', 'β Hydri', 'α Indi', 'α Lacertae',
#        'Regulus', 'Praecipua', 'Arneb', 'Zubeneschamali', 'α Lupi',
#        'α Lyncis', 'Vega', 'α Mensae', 'γ Microscopii', 'β Monocerotis',
#        'α Muscae', 'γ Normae', 'ν Octantis', 'Rasalhague', 'Rigel',
#        'Peacock', 'Enif', 'Mirfak', 'Ankaa', 'α Pictoris', 'Alpherg',
#        'Fomalhaut', 'Naos', 'α Pyxidis', 'α Reticuli', 'γ Sagittae',
#        'Kaus Australis', 'Antares', 'α Sculptoris', 'α Scuti',
#        'Unukalhai', 'α Sextantis', 'Aldebaran', 'α Telescopii',
#        'β Trianguli', 'Atria', 'α Tucanae', 'Alioth', 'Polaris',
#        'γ Velorum', 'Spica', 'β Volantis', 'Anser'], dtype=object)

# %% [markdown]
# ## Create the table for planet and its related star

# %%
df_planet_star = pd.merge(df_planet_constellation, 
                          df_constellation[['name', 'star']], 
                          how='inner', 
                          left_on='constellation', 
                          right_on='name')

df_planet_star = df_planet_star[['planet', 'star']]
df_planet_star = df_planet_star.rename(columns={'planet': 'name'})
df_planet_star
# Out:
#         name               star
# 0    Mercury              Spica
# 1      Venus            Regulus
# 2      Ceres            Regulus
# 3      Earth    Rigil Kentaurus
# 4       Mars          Aldebaran
# 5      Sedna          Aldebaran
# 6    Jupiter             Diphda
# 7       Eris             Diphda
# 8     Saturn       Deneb Algedi
# 9     Uranus              Hamal
# 10   Neptune          Sadalsuud
# 11  Gonggong          Sadalsuud
# 12     Varda          Sadalsuud
# 13     Orcus     Kaus Australis
# 14     Pluto     Kaus Australis
# 15    Haumea           Arcturus
# 16    Quaoar         Rasalhague
# 17  Makemake  β Comae Berenices
# 18   Salacia               Enif

# %% [markdown]
# ## Keep the Relevant Conestellations

# %%
keep_constellation = df_planet_constellation.constellation.unique() 
keep_constellation
# Out:
# array(['Virgo', 'Leo', 'Centaurus', 'Taurus', 'Cetus', 'Capricornus',
#        'Aries', 'Aquarius', 'Sagittarius', 'Boötes', 'Ophiuchus',
#        'Coma Berenices', 'Pegasus'], dtype=object)

# %%
df_constellation = df_constellation[df_constellation.name.isin(keep_constellation)]
df_constellation = df_constellation.reset_index(drop=True)
df_constellation
# Out:
#               name year_discovered  \
# 0         Aquarius
# 1            Aries
# 2           Boötes
# 3      Capricornus
# 4        Centaurus
# 5            Cetus
# 6   Coma Berenices            1536
# 7              Leo
# 8        Ophiuchus
# 9          Pegasus
# 10     Sagittarius
# 11          Taurus
# 12           Virgo
#
#                                        meaning               star
# 0                                 Water-bearer          Sadalsuud
# 1                                          Ram              Hamal
# 2                                     Herdsman           Arcturus
# 3                                     Sea goat       Deneb Algedi
# 4                                      Centaur    Rigil Kentaurus
# 5   Sea monster (later interpreted as a whale)             Diphda
# 6                              Berenice's hair  β Comae Berenices
# 7                                         Lion            Regulus
# 8                               Serpent-bearer         Rasalhague
# 9          Pegasus (mythological winged horse)               Enif
# 10                                      Archer     Kaus Australis
# 11                                        Bull          Aldebaran
# 12                            Virgin or maiden              Spica

# %% [markdown]
# ## Creating the Star Table

# %% [markdown]
# We will input the data manually as data scrapping will be too tedius.

# %%
star_dict = {
    'star_id' : list(range(1, 14)),
    'name' : ['Sadalsuud', 'Hamal', 'Arcturus', 'Deneb Algedi', 'Rigil Kentaurus', 'β Comae Berenices', 
              'Regulus', 'Aldebaran', 'Diphda', 'Enif', 'Kaus Australis', 'Rasalhague', 'Spica'],
    'distance_in_light_years' : [612.00, 66, 37.00, 39, 4.36, 30.00, 77.00, 
                                 65.23, 96.22, 688.2, 143.2, 48.6, 260.9],
    'brightness_of_star' : [2.90, 2.01, 0.05, 2.85, 0.01, 4.26, 1.36, 
                            0.85, 2.04, 2.4, 1.85, 2.08, 1.04],
    'approval_date' : ['2016-08-21', '2016-07-20', '2016-06-30', '2017-02-01', '2016-11-06', np.NaN, 
                       '2016-06-30', '2016-06-30', '2016-08-21', '2016-07-20', '2016-07-20', '2016-07-20', '2016-06-30'],
    'galaxy' : ['Milky Way'] * 13
}

df_star = pd.DataFrame.from_dict(star_dict)
df_star
# Out:
#     star_id               name  distance_in_light_years  brightness_of_star  \
# 0         1          Sadalsuud                   612.00                2.90
# 1         2              Hamal                    66.00                2.01
# 2         3           Arcturus                    37.00                0.05
# 3         4       Deneb Algedi                    39.00                2.85
# 4         5    Rigil Kentaurus                     4.36                0.01
# 5         6  β Comae Berenices                    30.00                4.26
# 6         7            Regulus                    77.00                1.36
# 7         8          Aldebaran                    65.23                0.85
# 8         9             Diphda                    96.22                2.04
# 9        10               Enif                   688.20                2.40
# 10       11     Kaus Australis                   143.20                1.85
# 11       12         Rasalhague                    48.60                2.08
# 12       13              Spica                   260.90                1.04
#
#    approval_date     galaxy
# 0     2016-08-21  Milky Way
# 1     2016-07-20  Milky Way
# 2     2016-06-30  Milky Way
# 3     2017-02-01  Milky Way
# 4     2016-11-06  Milky Way
# 5            NaN  Milky Way
# 6     2016-06-30  Milky Way
# 7     2016-06-30  Milky Way
# 8     2016-08-21  Milky Way
# 9     2016-07-20  Milky Way
# 10    2016-07-20  Milky Way
# 11    2016-07-20  Milky Way
# 12    2016-06-30  Milky Way

# %% [markdown]
# # Creating the final planet table

# %% [markdown]
# We can add a star_id column to the planet table now that we have (almost) completed the star table. Later, we will also replace the galaxy column in this star table with the galaxy_id.

# %%
# Add the star column to the planet table
df_planets = pd.merge(df_planets, df_planet_star, how='inner', on='name')

# Add the appropriate star_id to the planet table
df_planets = pd.merge(df_planets, df_star[['star_id', 'name']], how='inner', left_on='star', right_on='name')

# Omit the columns that are not needed
df_planets = df_planets.drop(columns=['star', 'name_y'])

# Change back the name of planet column to "name"
df_planets = df_planets.rename(columns={'name_x' : 'name'})

# Sort planet_id column and reset the index
df_planets = df_planets.sort_values(by='planet_id').reset_index(drop=True)

# Display the table
df_planets
# Out:
#     planet_id      name orbital_period_in_years rotation_period_in_days  \
# 0           1   Mercury                    0.24                   58.65
# 1           2     Venus                    0.62                  243.02
# 2           3     Earth                    1.00                    1.00
# 3           4      Mars                    1.88                    1.03
# 4           5   Jupiter                   11.86                    0.41
# 5           6    Saturn                   29.45                    0.44
# 6           7    Uranus                   84.02                    0.72
# 7           8   Neptune                  164.79                    0.67
# 8           9     Ceres                    4.60                    0.38
# 9          10     Orcus                   247.5                     NaN
# 10         11     Pluto                   247.9                    6.39
# 11         12    Haumea                   283.8                    0.16
# 12         13    Quaoar                   288.0                    0.74
# 13         14  Makemake                   306.2                    0.95
# 14         15  Gonggong                   552.5                    0.93
# 15         16      Eris                     559                   15.79
# 16         17     Sedna                   12059                    0.43
#
#     has_moon  star_id
# 0      False       13
# 1      False        7
# 2       True        5
# 3       True        8
# 4       True        9
# 5       True        4
# 6       True        2
# 7       True        1
# 8      False        7
# 9       True       11
# 10      True       11
# 11      True        3
# 12      True       12
# 13      True        6
# 14      True        1
# 15      True        9
# 16     False        8

# %% [markdown]
# # Creating the constellation table (final)

# %%
# Add the appropriate star_id to the constellation table
df_constellation = pd.merge(df_constellation, df_star[['star_id', 'name']], how='inner', left_on='star', right_on='name')

# Omit the columns that are not needed
df_constellation = df_constellation.drop(columns=['star', 'name_y'])

# Change back the name of planet column to "name"
df_constellation = df_constellation.rename(columns={'name_x' : 'name'})

# Add the "constellation_id" column
df_constellation.reset_index(inplace=True)
df_constellation.rename(columns={'index': 'constellation_id'}, inplace=True)
df_constellation['constellation_id'] += 1

# Display the table
df_constellation
# Out:
#     constellation_id            name year_discovered  \
# 0                  1        Aquarius
# 1                  2           Aries
# 2                  3          Boötes
# 3                  4     Capricornus
# 4                  5       Centaurus
# 5                  6           Cetus
# 6                  7  Coma Berenices            1536
# 7                  8             Leo
# 8                  9       Ophiuchus
# 9                 10         Pegasus
# 10                11     Sagittarius
# 11                12          Taurus
# 12                13           Virgo
#
#                                        meaning  star_id
# 0                                 Water-bearer        1
# 1                                          Ram        2
# 2                                     Herdsman        3
# 3                                     Sea goat        4
# 4                                      Centaur        5
# 5   Sea monster (later interpreted as a whale)        9
# 6                              Berenice's hair        6
# 7                                         Lion        7
# 8                               Serpent-bearer       12
# 9          Pegasus (mythological winged horse)       10
# 10                                      Archer       11
# 11                                        Bull        8
# 12                            Virgin or maiden       13

# %% [markdown]
# # Creating the last table: galaxy table (final)

# %%
page = requests.get('https://littleastronomy.com/galaxy-names/')
soup = BeautifulSoup(page.text, 'lxml')

# Initialize the table
headers = ['name', 'designation', 'constellation', 'meaning']
df_galaxy = pd.DataFrame(columns = headers)

# Enter data for each row into the dataframe
table = soup.find("table")
for table_row in table.find_all('tr')[1:]:
  data = [table_data.text.strip() for table_data in table_row.find_all('td')]
  df_galaxy.loc[len(df_galaxy)] = data

# Delete "designation" column
df_galaxy = df_galaxy.drop(columns='designation')

# Add the contellation (center) of Milky Way 
df_galaxy.loc[26, 'constellation'] = 'Sagittarius'

# Show a snippet of the table.
df_galaxy.head(10)
# Out:
#                  name   constellation  \
# 0           Andromeda       Andromeda
# 1     Antennae Galaxy          Corvus
# 2     Backward Galaxy       Centaurus
# 3    Black Eye Galaxy  Coma Berenices
# 4       Bode’s Galaxy      Ursa Major
# 5  Butterfly Galaxies           Virgo
# 6    Cartwheel Galaxy        Sculptor
# 7         Centaurus A       Centaurus
# 8        Cigar Galaxy      Ursa Major
# 9            Circinus        Circinus
#
#                                              meaning
# 0  In mythology, Andromeda is the daughter of the...
# 1  This is a dual galaxy. It gets its name becaus...
# 2  It seems to rotate in the opposite direction t...
# 3  It looks like an eye with a dark stripe undern...
# 4  Named after the astronomer who discovered it, ...
# 5  Binary galaxies. It looks like a pair of butte...
# 6                    It looks a bit like a cartwheel
# 7  Named because it’s located in the Centaurus co...
# 8                          It is shaped like a cigar
# 9  Latin for compass. Named after the constellati...

# %%
kept_constellation = df_constellation.name.values
df_galaxy = df_galaxy[df_galaxy.constellation.isin(kept_constellation)].reset_index(drop=True)
df_galaxy
# Out:
#                       name   constellation  \
# 0          Backward Galaxy       Centaurus
# 1         Black Eye Galaxy  Coma Berenices
# 2       Butterfly Galaxies           Virgo
# 3              Centaurus A       Centaurus
# 4     Coma Pinwheel Galaxy  Coma Berenices
# 5   Little Sombrero Galaxy         Pegasus
# 6                  Malin 1  Coma Berenices
# 7            Mice Galaxies  Coma Berenices
# 8                Milky Way     Sagittarius
# 9            Needle Galaxy  Coma Berenices
# 10   Wolf-Lundmark-Melotte           Cetus
# 11         Sombrero Galaxy           Virgo
#
#                                               meaning
# 0   It seems to rotate in the opposite direction t...
# 1   It looks like an eye with a dark stripe undern...
# 2   Binary galaxies. It looks like a pair of butte...
# 3   Named because it’s located in the Centaurus co...
# 4                      It looks like a paper pinwheel
# 5   It looks like a sombrero, but it’s smaller tha...
# 6             Named after its discoverer, David Malin
# 7   Two galaxies with long tails that look like a ...
# 8   Our own galaxy. It is said to look like a band...
# 9                Named because of its thin appearance
# 10  Named after the astronomers that co-discovered it
# 11                              Looks like a sombrero

# %%
visible_galaxy = ['Milky Way', 'Large Magellanic Cloud', 'Small Magellanic Cloud', 'Andromeda', 
                  'Triangulum Galaxy', 'Centaurus A', 'Bode’s Galaxy', 'Sculptor Galaxy']
df_galaxy['is_visible_to_naked_eye'] = df_galaxy.apply(lambda row : True if row['name'] in visible_galaxy else False, axis=1)
df_galaxy
# Out:
#                       name   constellation  \
# 0          Backward Galaxy       Centaurus
# 1         Black Eye Galaxy  Coma Berenices
# 2       Butterfly Galaxies           Virgo
# 3              Centaurus A       Centaurus
# 4     Coma Pinwheel Galaxy  Coma Berenices
# 5   Little Sombrero Galaxy         Pegasus
# 6                  Malin 1  Coma Berenices
# 7            Mice Galaxies  Coma Berenices
# 8                Milky Way     Sagittarius
# 9            Needle Galaxy  Coma Berenices
# 10   Wolf-Lundmark-Melotte           Cetus
# 11         Sombrero Galaxy           Virgo
#
#                                               meaning  is_visible_to_naked_eye
# 0   It seems to rotate in the opposite direction t...                    False
# 1   It looks like an eye with a dark stripe undern...                    False
# 2   Binary galaxies. It looks like a pair of butte...                    False
# 3   Named because it’s located in the Centaurus co...                     True
# 4                      It looks like a paper pinwheel                    False
# 5   It looks like a sombrero, but it’s smaller tha...                    False
# 6             Named after its discoverer, David Malin                    False
# 7   Two galaxies with long tails that look like a ...                    False
# 8   Our own galaxy. It is said to look like a band...                     True
# 9                Named because of its thin appearance                    False
# 10  Named after the astronomers that co-discovered it                    False
# 11                              Looks like a sombrero                    False

# %%
# Add the appropriate constellation_id to the galaxy table
df_galaxy = pd.merge(df_galaxy, 
                     df_constellation[['constellation_id', 'name']], 
                     how='inner', 
                     left_on='constellation', 
                     right_on='name')

# Omit the columns that are not needed
df_galaxy = df_galaxy.drop(columns=['constellation', 'name_y'])

# Change back the name of planet column to "name"
df_galaxy = df_galaxy.rename(columns={'name_x' : 'name'})

# Add the "galaxy_id" column
df_galaxy.reset_index(inplace=True)
df_galaxy.rename(columns={'index': 'galaxy_id'}, inplace=True)
df_galaxy['galaxy_id'] += 1

# Display the table
df_galaxy
# Out:
#     galaxy_id                    name  \
# 0           1         Backward Galaxy
# 1           2             Centaurus A
# 2           3        Black Eye Galaxy
# 3           4    Coma Pinwheel Galaxy
# 4           5                 Malin 1
# 5           6           Mice Galaxies
# 6           7           Needle Galaxy
# 7           8      Butterfly Galaxies
# 8           9         Sombrero Galaxy
# 9          10  Little Sombrero Galaxy
# 10         11               Milky Way
# 11         12   Wolf-Lundmark-Melotte
#
#                                               meaning  \
# 0   It seems to rotate in the opposite direction t...
# 1   Named because it’s located in the Centaurus co...
# 2   It looks like an eye with a dark stripe undern...
# 3                      It looks like a paper pinwheel
# 4             Named after its discoverer, David Malin
# 5   Two galaxies with long tails that look like a ...
# 6                Named because of its thin appearance
# 7   Binary galaxies. It looks like a pair of butte...
# 8                               Looks like a sombrero
# 9   It looks like a sombrero, but it’s smaller tha...
# 10  Our own galaxy. It is said to look like a band...
# 11  Named after the astronomers that co-discovered it
#
#     is_visible_to_naked_eye  constellation_id
# 0                     False                 5
# 1                      True                 5
# 2                     False                 7
# 3                     False                 7
# 4                     False                 7
# 5                     False                 7
# 6                     False                 7
# 7                     False                13
# 8                     False                13
# 9                     False                10
# 10                     True                11
# 11                    False                 6

# %% [markdown]
# # Final Tables

# %%
df_star['galaxy_id'] = [11] * len(df_star) 
df_star = df_star.drop(columns='galaxy')

# %%
df_constellation
# Out:
#     constellation_id            name year_discovered  \
# 0                  1        Aquarius
# 1                  2           Aries
# 2                  3          Boötes
# 3                  4     Capricornus
# 4                  5       Centaurus
# 5                  6           Cetus
# 6                  7  Coma Berenices            1536
# 7                  8             Leo
# 8                  9       Ophiuchus
# 9                 10         Pegasus
# 10                11     Sagittarius
# 11                12          Taurus
# 12                13           Virgo
#
#                                        meaning  star_id
# 0                                 Water-bearer        1
# 1                                          Ram        2
# 2                                     Herdsman        3
# 3                                     Sea goat        4
# 4                                      Centaur        5
# 5   Sea monster (later interpreted as a whale)        9
# 6                              Berenice's hair        6
# 7                                         Lion        7
# 8                               Serpent-bearer       12
# 9          Pegasus (mythological winged horse)       10
# 10                                      Archer       11
# 11                                        Bull        8
# 12                            Virgin or maiden       13

# %%
df_galaxy
# Out:
#     galaxy_id                    name  \
# 0           1         Backward Galaxy
# 1           2             Centaurus A
# 2           3        Black Eye Galaxy
# 3           4    Coma Pinwheel Galaxy
# 4           5                 Malin 1
# 5           6           Mice Galaxies
# 6           7           Needle Galaxy
# 7           8      Butterfly Galaxies
# 8           9         Sombrero Galaxy
# 9          10  Little Sombrero Galaxy
# 10         11               Milky Way
# 11         12   Wolf-Lundmark-Melotte
#
#                                               meaning  \
# 0   It seems to rotate in the opposite direction t...
# 1   Named because it’s located in the Centaurus co...
# 2   It looks like an eye with a dark stripe undern...
# 3                      It looks like a paper pinwheel
# 4             Named after its discoverer, David Malin
# 5   Two galaxies with long tails that look like a ...
# 6                Named because of its thin appearance
# 7   Binary galaxies. It looks like a pair of butte...
# 8                               Looks like a sombrero
# 9   It looks like a sombrero, but it’s smaller tha...
# 10  Our own galaxy. It is said to look like a band...
# 11  Named after the astronomers that co-discovered it
#
#     is_visible_to_naked_eye  constellation_id
# 0                     False                 5
# 1                      True                 5
# 2                     False                 7
# 3                     False                 7
# 4                     False                 7
# 5                     False                 7
# 6                     False                 7
# 7                     False                13
# 8                     False                13
# 9                     False                10
# 10                     True                11
# 11                    False                 6

# %%
df_star
# Out:
#     star_id               name  distance_in_light_years  brightness_of_star  \
# 0         1          Sadalsuud                   612.00                2.90
# 1         2              Hamal                    66.00                2.01
# 2         3           Arcturus                    37.00                0.05
# 3         4       Deneb Algedi                    39.00                2.85
# 4         5    Rigil Kentaurus                     4.36                0.01
# 5         6  β Comae Berenices                    30.00                4.26
# 6         7            Regulus                    77.00                1.36
# 7         8          Aldebaran                    65.23                0.85
# 8         9             Diphda                    96.22                2.04
# 9        10               Enif                   688.20                2.40
# 10       11     Kaus Australis                   143.20                1.85
# 11       12         Rasalhague                    48.60                2.08
# 12       13              Spica                   260.90                1.04
#
#    approval_date  galaxy_id
# 0     2016-08-21         11
# 1     2016-07-20         11
# 2     2016-06-30         11
# 3     2017-02-01         11
# 4     2016-11-06         11
# 5            NaN         11
# 6     2016-06-30         11
# 7     2016-06-30         11
# 8     2016-08-21         11
# 9     2016-07-20         11
# 10    2016-07-20         11
# 11    2016-07-20         11
# 12    2016-06-30         11

# %%
df_star.to_excel('star.xlsx')

# %%
df_planets
# Out:
#     planet_id      name orbital_period_in_years rotation_period_in_days  \
# 0           1   Mercury                    0.24                   58.65
# 1           2     Venus                    0.62                  243.02
# 2           3     Earth                    1.00                    1.00
# 3           4      Mars                    1.88                    1.03
# 4           5   Jupiter                   11.86                    0.41
# 5           6    Saturn                   29.45                    0.44
# 6           7    Uranus                   84.02                    0.72
# 7           8   Neptune                  164.79                    0.67
# 8           9     Ceres                    4.60                    0.38
# 9          10     Orcus                   247.5                     NaN
# 10         11     Pluto                   247.9                    6.39
# 11         12    Haumea                   283.8                    0.16
# 12         13    Quaoar                   288.0                    0.74
# 13         14  Makemake                   306.2                    0.95
# 14         15  Gonggong                   552.5                    0.93
# 15         16      Eris                     559                   15.79
# 16         17     Sedna                   12059                    0.43
#
#     has_moon  star_id
# 0      False       13
# 1      False        7
# 2       True        5
# 3       True        8
# 4       True        9
# 5       True        4
# 6       True        2
# 7       True        1
# 8      False        7
# 9       True       11
# 10      True       11
# 11      True        3
# 12      True       12
# 13      True        6
# 14      True        1
# 15      True        9
# 16     False        8

# %%
sql_command = 'INSERT INTO planet(name, orbital_period_in_years, rotation_period_in_days, has_moon, star_id) VALUES'

for i in range(len(df_planets)):
    planet = df_planets.loc[i]
    sql_command += "('" + planet['name'] + "', " + str(planet['orbital_period_in_years']) + ', ' + str(planet['rotation_period_in_days']) + ', ' + str(planet['has_moon']) + ', ' + str(planet['star_id'])
    if i == len(df_planets) - 1: 
        sql_command += ');'
    else:
        sql_command += '), '

print(sql_command);
# Out:
# INSERT INTO planet(name, orbital_period_in_years, rotation_period_in_days, has_moon, star_id) VALUES('Mercury', 0.24, 58.65, False, 13), ('Venus', 0.62, 243.02, False, 7), ('Earth', 1.00, 1.00, True, 5), ('Mars', 1.88, 1.03, True, 8), ('Jupiter', 11.86, 0.41, True, 9), ('Saturn', 29.45, 0.44, True, 4), ('Uranus', 84.02, 0.72, True, 2), ('Neptune', 164.79, 0.67, True, 1), ('Ceres', 4.60, 0.38, False, 7), ('Orcus', 247.5, nan, True, 11), ('Pluto', 247.9, 6.39, True, 11), ('Haumea', 283.8, 0.16, True, 3), ('Quaoar', 288.0, 0.74, True, 12), ('Makemake', 306.2, 0.95, True, 6), ('Gonggong', 552.5, 0.93, True, 1), ('Eris', 559, 15.79, True, 9), ('Sedna', 12059, 0.43, False, 8);

# %%
df_moon_merged
# Out:
#           name                                       name_meaning  \
# 0       Phobos                        Greek god of fear and panic
# 1       Deimos                      Greek god of dread and terror
# 2           Io   Ancestor to Perseus, Cadmus, Heracles, and Minos
# 3       Europa                      Mother of king Minos of Crete
# 4     Ganymede  Male hero of Troy. Served as Zeus cup-bearer i...
# 5     Callisto  One of the nymphs. Daughter of king Lycaon and...
# 6     Amalthea                              Foster-mother of Zeus
# 7      Himalia  Nymph of the island of Rhodes. Had three sons ...
# 8        Thebe  Name used by a few of Zeus’ daughters. It is a...
# 9        Mimas  One of the Gigantes (giants). Son of Gaia (Earth)
# 10   Enceladus  One of the Gigantes (giants). Son of Gaia (Ear...
# 11      Tethys         One of the Titans. Mother of the Oceanids.
# 12       Dione                                  One of the Titans
# 13        Rhea         One of the Titans. Older sister of Cronus.
# 14       Titan                       Named after the Greek Titans
# 15    Hyperion  Titan god of observation. Father of Helios, Eo...
# 16     Iapetus  One of the Titans. Father of Atlas and Prometh...
# 17      Phoebe  One of the first generation Titaness. It means...
# 18       Janus  Roman god of beginnings, duality, time, and do...
# 19  Epimetheus           One of the Titans. Brother of Prometheus
# 20       Atlas  One of the Titans. Condemned to hold up the sk...
# 21  Prometheus  One of the Titans. Known for stealing the fire...
# 22     Pandora  Also known as Anesidora.It means “she who send...
# 23         Pan             God of the wild, sheperds, and flocks.
# 24       Ariel  Named after a character in Alexander Pope’s wo...
# 25     Umbriel  Named after the “dusky melancholy sprite” in A...
# 26     Titania  Named after a charcter in Shakespeare’s play A...
# 27      Oberon  Named after a charcter in Shakespeare’s play A...
# 28     Miranda  Named after a charcter in Shakespeare’s play T...
# 29        Puck  Named after a charcter in Shakespeare’s play A...
# 30      Triton              Greek god of the sea. Son of Poseidon
# 31      Nereid  Named after the Nereids, the sea-nymphs of Gre...
# 32     Despina  Also known as Despoina. One of Poseidon’s daug...
# 33     Galatea              One of the Nereids in Greek mythology
# 34     Larissa             Nymph from Thelassy in Greek mythology
# 35         Nix                          Geek Goddess of the night
#
#    year_discovered diameter_in_km  planet_id
# 0             1877             23          4
# 1             1877             13          4
# 2             1610           3630          5
# 3             1610           3138          5
# 4             1610           5262          5
# 5             1610           4800          5
# 6             1892            200          5
# 7             1904            170          5
# 8             1979             90          5
# 9             1789            394          6
# 10            1789            502          6
# 11            1684           1048          6
# 12            1684           1120          6
# 13            1672           1530          6
# 14            1655           5150          6
# 15            1848            270          6
# 16            1671           1435          6
# 17            1898            220          6
# 18            1966            190          6
# 19            1980            120          6
# 20            1980             40          6
# 21            1980             80          6
# 22            1980            100          6
# 23            1985             20          6
# 24            1851           1160          7
# 25            1851           1190          7
# 26            1787           1610          7
# 27            1787           1550          7
# 28            1948            485          7
# 29            1985            170          7
# 30            1846           2720          8
# 31            1949            340          8
# 32            1989            150          8
# 33            1989            150          8
# 34            1989            400          8
# 35            2005             46         11

# %%
sql_command = 'INSERT INTO moon(name, name_meaning, year_discovered, diameter_in_km, planet_id) VALUES'

for i in range(len(df_moon_merged)):
    moon = df_moon_merged.loc[i]
    sql_command += "('" + moon['name'] + "', '" + moon['name_meaning'] + "', " + str(moon['year_discovered']) + ', ' + str(moon['diameter_in_km']) + ', ' + str(planet['planet_id'])
    if i == len(df_moon_merged) - 1: 
        sql_command += ');'
    else:
        sql_command += '), '

print(sql_command);
# Out:
# INSERT INTO moon(name, name_meaning, year_discovered, diameter_in_km, planet_id) VALUES('Phobos', 'Greek god of fear and panic', 1877, 23, 17), ('Deimos', 'Greek god of dread and terror', 1877, 13, 17), ('Io', 'Ancestor to Perseus, Cadmus, Heracles, and Minos', 1610, 3630, 17), ('Europa', 'Mother of king Minos of Crete', 1610, 3138, 17), ('Ganymede', 'Male hero of Troy. Served as Zeus cup-bearer in Olympus', 1610, 5262, 17), ('Callisto', 'One of the nymphs. Daughter of king Lycaon and one of Artemis followers', 1610, 4800, 17), ('Amalthea', 'Foster-mother of Zeus', 1892, 200, 17), ('Himalia', 'Nymph of the island of Rhodes. Had three sons with Zeus: Sparteus, Kronios and Kytos', 1904, 170, 17), ('Thebe', 'Name used by a few of Zeus’ daughters. It is also the name of a city in central Greece.', 1979, 90, 17), ('Mimas', 'One of the Gigantes (giants). Son of Gaia (Earth)', 1789, 394, 17), ('Enceladus', 'One of the Gigantes (giants). Son of Gaia (Earth) and Uranus (Sky)', 1789, 502, 17), ('Tethys', 'One of the Titans. Mother of the Oceanids.', 1684, 1048, 17), ('Dione', 'One of the Titans', 1684, 1120, 17), ('Rhea', 'One of the Titans. Older sister of Cronus.', 1672, 1530, 17), ('Titan', 'Named after the Greek Titans', 1655, 5150, 17), ('Hyperion', 'Titan god of observation. Father of Helios, Eos, and Selene (the Moon)', 1848, 270, 17), ('Iapetus', 'One of the Titans. Father of Atlas and Prometheus. Also written as Japetus', 1671, 1435, 17), ('Phoebe', 'One of the first generation Titaness. It means “shining” or “bright”. Original owner of the oracle of Delphi.', 1898, 220, 17), ('Janus', 'Roman god of beginnings, duality, time, and doorways.', 1966, 190, 17), ('Epimetheus', 'One of the Titans. Brother of Prometheus', 1980, 120, 17), ('Atlas', 'One of the Titans. Condemned to hold up the sky for eternity after the Titanomachy', 1980, 40, 17), ('Prometheus', 'One of the Titans. Known for stealing the fire of the gods and gifting it to humanity', 1980, 80, 17), ('Pandora', 'Also known as Anesidora.It means “she who sends up gifts”', 1980, 100, 17), ('Pan', 'God of the wild, sheperds, and flocks.', 1985, 20, 17), ('Ariel', 'Named after a character in Alexander Pope’s works.', 1851, 1160, 17), ('Umbriel', 'Named after the “dusky melancholy sprite” in Alexander Pope’s works.', 1851, 1190, 17), ('Titania', 'Named after a charcter in Shakespeare’s play A Midsummer Night’s Dream', 1787, 1610, 17), ('Oberon', 'Named after a charcter in Shakespeare’s play A Midsummer Night’s Dream', 1787, 1550, 17), ('Miranda', 'Named after a charcter in Shakespeare’s play The Tempest', 1948, 485, 17), ('Puck', 'Named after a charcter in Shakespeare’s play A Midsummer Night’s Dream', 1985, 170, 17), ('Triton', 'Greek god of the sea. Son of Poseidon', 1846, 2720, 17), ('Nereid', 'Named after the Nereids, the sea-nymphs of Greek mythology', 1949, 340, 17), ('Despina', 'Also known as Despoina. One of Poseidon’s daughter', 1989, 150, 17), ('Galatea', 'One of the Nereids in Greek mythology', 1989, 150, 17), ('Larissa', 'Nymph from Thelassy in Greek mythology', 1989, 400, 17), ('Nix', 'Geek Goddess of the night', 2005, 46, 17);
